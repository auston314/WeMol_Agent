# %%
from content_tree import *
import requests
import json
import pickle
import time
import re
from typing import Dict, List, Tuple

TERM_LINE_RE = re.compile(
    r'^\s*(?:[-*]\s*)?\*\*(.+?)\*\*\s*(?:[:\-–—])?\s*(.*)\s*$'
)

def _clean(text: str) -> str:
    # Strip surrounding bold markers if any, normalize whitespace
    text = text.strip()
    if text.startswith("**") and text.endswith("**") and len(text) >= 4:
        text = text[2:-2].strip()
    # Collapse whitespace, keep LaTeX and symbols intact
    text = re.sub(r'[ \t]+', ' ', text)
    text = re.sub(r'\s*\n\s*', ' ', text)
    return text.strip(' |')

def _parse_table_block(lines: List[str], start: int) -> Tuple[Dict[str, str], int]:
    """
    Parse a markdown table starting at index `start` (assumes header present).
    Returns (rows_dict, next_index_after_table)
    """
    out: Dict[str, str] = {}
    i = start
    # consume header
    header = lines[i].strip()
    i += 1
    # optional separator row(s)
    while i < len(lines) and lines[i].lstrip().startswith('|') and set(lines[i].replace('|', '').strip()) <= set('-: '):
        i += 1

    # consume data rows
    while i < len(lines) and lines[i].lstrip().startswith('|'):
        row = lines[i].strip().strip('|')
        cells = [c.strip() for c in row.split('|')]
        if len(cells) >= 2:
            term = _clean(cells[0])
            definition = _clean(cells[1])
            if term:
                # prefer longer definition if duplicate
                if term not in out or len(definition) > len(out[term]):
                    out[term] = definition
        i += 1
    return out, i

def _collect_until(next_breaks: set, i: int, lines: List[str], start_at: int) -> Tuple[str, int]:
    """
    Collect definition lines from start_at until index in next_breaks or EOF.
    Returns (definition, next_index)
    """
    parts: List[str] = []
    j = start_at
    while j < len(lines) and j not in next_breaks:
        parts.append(lines[j].rstrip())
        j += 1
    # Trim leading/trailing blank lines from collected parts
    while parts and not parts[0].strip():
        parts.pop(0)
    while parts and not parts[-1].strip():
        parts.pop()
    return _clean('\n'.join(parts)), j

def parse_key_terms(text: str) -> Dict[str, str]:
    """
    Extract key terms and definitions from heterogeneous markdown-like samples.
    Supports:
      - Markdown tables with 'Term' and 'Definition' columns
      - Bulleted lines like: - **term**  definition
      - Bold term on a line; definition on same or following lines
    """
    lines = text.splitlines()
    n = len(lines)
    i = 0
    result: Dict[str, str] = {}

    # First pass: detect table blocks (by header)
    table_headers = set()
    idx = 0
    while idx < n:
        line = lines[idx].strip()
        if line.startswith('|') and 'Term' in line and 'Definition' in line:
            table_headers.add(idx)
            # skip parsing here; we’ll parse in main loop
        idx += 1

    # Precompute term-line indices (non-table)
    term_line_indices = set()
    for idx, line in enumerate(lines):
        if idx in table_headers:
            continue
        if line.lstrip().startswith('|'):
            continue  # table content; will be parsed in table handler
        if TERM_LINE_RE.match(line):
            term_line_indices.add(idx)

    # Main scan
    while i < n:
        line = lines[i]

        # Table?
        if i in table_headers:
            rows, i_next = _parse_table_block(lines, i)
            for k, v in rows.items():
                if k not in result or len(v) > len(result[k]):
                    result[k] = v
            i = i_next
            continue

        # Term line?
        m = TERM_LINE_RE.match(line)
        if m:
            term = _clean(m.group(1))
            inline_def = _clean(m.group(2)) if m.group(2) else ''
            if inline_def:
                definition = inline_def
                i += 1
            else:
                # Collect until next term/table start
                # Build set of break indices >= i+1
                next_breaks = set(j for j in term_line_indices if j > i) | set(k for k in table_headers if k > i)
                definition, i_after = _collect_until(next_breaks, i, lines, i + 1)
                i = i_after
            if term and definition:
                if term not in result or len(definition) > len(result[term]):
                    result[term] = definition
            continue

        i += 1

    return result

# %%
# Create a content tree
tree = ContentTree()

# copy some md files into this test folder so that you can test only one or a few md files!
md_directory = "./md_files"
print(f"Building tree from: {md_directory}")
tree.build_textbook_tree(md_directory, max_level=4)

# Rename repeating headers to make them unique
tree.rename_repeating_headers()
nodes = tree.tree_node_iterator()
print(len(nodes))

with open('genchem.pkl','wb') as f:
    pickle.dump(tree, f)
# Out:
# Building tree from: ./md_files
# 1218

# %%
# Build key term dictionary for the content tree
with open('genchem.pkl', 'rb') as f:
    tree = pickle.load(f)
    
nodes = tree.tree_node_iterator()

key_term_dict = {}
for node in nodes:
    if (node.header.find(" Key Terms") > -1):
        print(node.header)
        terms = parse_key_terms(node.content_text)
        print("Key terms = ", len(terms))
        key_term_dict.update(terms)
# Print a few to verify
print("Total terms = ", len(key_term_dict))
with open('key_term_dict.pkl','wb') as f:
    pickle.dump(key_term_dict, f)
# Out:
# Chapter 1 Key Terms
# Key terms =  52
# Chapter 2 Key Terms
# Key terms =  61
# Chapter 3 Key Terms
# Key terms =  20
# Chapter 4 Key Terms
# Key terms =  49
# Chapter 5 Key Terms
# Key terms =  32
# Chapter 6 Key Terms
# Key terms =  50
# Chapter 7 Key Terms
# Key terms =  39
# Chapter 8 Key Terms
# Key terms =  28
# Chapter 9 Key Terms
# Key terms =  32
# Chapter 10 Key Terms
# Key terms =  56
# Chapter 11 Key Terms
# Key terms =  44
# Chapter 12 Key Terms
# Key terms =  29
# Solution Key Terms
# Key terms =  8
# Chapter 14 Key Terms
# Key terms =  31
# Chapter 15 Key Terms
# Key terms =  14
# Chapter 16 Key Terms
# Key terms =  12
# Chapter 17 Key Terms
# Key terms =  31
# Chapter 18 Key Terms
# Key terms =  42
# Chapter 19 Key Terms
# Key terms =  41
# Chapter 20 Key Terms
# Key terms =  21
# Chapter 21 Key Terms
# Key terms =  67
# Total terms =  747

# %%
# Process content for all tree nodes
# Load content tree with partically processed without embedding

with open('genchem_no_embedding.pkl', 'rb') as f:
    tree = pickle.load(f)
    
nodes = tree.tree_node_iterator()
for node in nodes:
    if (node.node_id in [20, 30, 50])
    if (node.header.find(" Key Terms") > -1 or node.header.find(" Summary") > -1 or node.header.find(" Exercises") > -1 or node.header.find("Root") > -1 or node.header.find("Preface") > -1 or node.header.find(" Key Equations") > -1):
        continue
    print("Node ID = ",node.node_id)
    node.process_content(llm_type="openai",llm_model="gpt-4o", llm_api_url="", generate_embeddings=True)
# Out:
# Node ID =  25
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  26
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  27
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  28
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  29
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 27 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Node ID =  30
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 44 texts in 2 batches...
# Generating embeddings for 30 texts in 1 batches...
# Node ID =  31
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Generating embeddings for 47 texts in 2 batches...
# Generating embeddings for 33 texts in 2 batches...
# Node ID =  32
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 37 texts in 2 batches...
# Generating embeddings for 25 texts in 1 batches...
# Node ID =  33
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  34
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  35
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 34 texts in 2 batches...
# Generating embeddings for 25 texts in 1 batches...
# Node ID =  36
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 21 texts in 1 batches...
# Node ID =  37
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Node ID =  38
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  39
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  40
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  41
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  42
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  43
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  44
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  45
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Node ID =  46
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  47
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  48
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  49
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 39 texts in 2 batches...
# Generating embeddings for 27 texts in 1 batches...
# Node ID =  50
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  51
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  52
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  53
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  54
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  55
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  56
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  57
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  58
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  59
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  60
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  61
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  62
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 22 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Node ID =  63
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  64
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  81
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  82
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Node ID =  83
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 33 texts in 2 batches...
# Generating embeddings for 24 texts in 1 batches...
# Node ID =  84
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Node ID =  85
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Generating embeddings for 74 texts in 3 batches...
# Generating embeddings for 60 texts in 2 batches...
# Node ID =  86
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 36 texts in 2 batches...
# Generating embeddings for 28 texts in 1 batches...
# Node ID =  87
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  88
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  89
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Node ID =  90
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  91
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  92
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Node ID =  93
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 50 texts in 2 batches...
# Generating embeddings for 35 texts in 2 batches...
# Node ID =  94
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  95
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Generating embeddings for 21 texts in 1 batches...
# Node ID =  96
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 41 texts in 2 batches...
# Generating embeddings for 33 texts in 2 batches...
# Node ID =  97
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  98
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Node ID =  99
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  100
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 36 texts in 2 batches...
# Generating embeddings for 27 texts in 1 batches...
# Node ID =  101
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Node ID =  102
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  103
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  104
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  105
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  106
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  107
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  108
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  109
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  110
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  111
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  112
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  113
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  114
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  115
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  116
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  117
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  118
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  119
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  138
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  139
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  140
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  141
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  142
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  143
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  144
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  145
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 34 texts in 2 batches...
# Generating embeddings for 30 texts in 1 batches...
# Node ID =  146
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  147
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  148
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  149
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  150
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  151
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  152
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 26 texts in 1 batches...
# Generating embeddings for 23 texts in 1 batches...
# Node ID =  153
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  154
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  155
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  156
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  157
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  158
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Node ID =  159
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  160
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  161
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  162
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  163
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  164
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  165
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  166
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  167
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  168
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  169
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  170
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  171
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  172
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  173
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  174
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  175
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  176
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  177
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  178
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  179
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  180
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  181
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  182
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  183
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  196
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  197
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 23 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Node ID =  198
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 21 texts in 1 batches...
# Node ID =  199
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 30 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 23 texts in 1 batches...
# Node ID =  200
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  201
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Node ID =  202
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  203
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  204
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 21 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Node ID =  205
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  206
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 25 texts in 1 batches...
# Generating embeddings for 35 texts in 2 batches...
# Generating embeddings for 35 texts in 2 batches...
# Node ID =  207
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  208
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  209
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  210
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Node ID =  211
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 22 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Node ID =  212
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  213
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 24 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  214
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  215
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Generating embeddings for 38 texts in 2 batches...
# Generating embeddings for 25 texts in 1 batches...
# Node ID =  216
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Node ID =  217
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  218
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  219
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  220
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  221
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  222
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  223
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 22 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Node ID =  224
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Node ID =  225
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  226
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  227
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  228
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  229
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  230
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  231
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  232
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  233
# Process node content ........
# ...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Node ID =  1151
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  1152
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  1153
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Generating embeddings for 27 texts in 1 batches...
# Generating embeddings for 30 texts in 1 batches...
# Node ID =  1154
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 42 texts in 2 batches...
# Generating embeddings for 31 texts in 1 batches...
# Node ID =  1155
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  1156
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  1157
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  1158
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1159
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  1160
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  1161
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 44 texts in 2 batches...
# Generating embeddings for 35 texts in 2 batches...
# Node ID =  1162
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 24 texts in 1 batches...
# Generating embeddings for 21 texts in 1 batches...
# Node ID =  1163
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 26 texts in 1 batches...
# Generating embeddings for 59 texts in 2 batches...
# Generating embeddings for 43 texts in 2 batches...
# Node ID =  1164
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Node ID =  1165
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  1166
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Node ID =  1167
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  1168
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 9 texts in 1 batches...
# Generating embeddings for 20 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Node ID =  1169
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  1170
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 10 texts in 1 batches...
# Node ID =  1171
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  1188
# Process node content ........
# Generating summary...
# Generating keywords...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1189
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Node ID =  1190
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1191
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1192
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1193
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1194
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1195
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1196
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1197
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1198
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1199
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Node ID =  1200
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1201
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1202
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Generating embeddings for 11 texts in 1 batches...
# Node ID =  1203
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1204
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  1205
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Node ID =  1206
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 4 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1207
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 5 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Node ID =  1208
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 19 texts in 1 batches...
# Node ID =  1209
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Node ID =  1210
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 18 texts in 1 batches...
# Generating embeddings for 7 texts in 1 batches...
# Generating embeddings for 17 texts in 1 batches...
# Node ID =  1211
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 8 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Node ID =  1212
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Error generating embeddings for batch 1: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens, however you requested 13145 tokens (13145 in your prompt; 0 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 124 texts in 4 batches...
# Node ID =  1213
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 32 texts in 1 batches...
# Generating embeddings for 16 texts in 1 batches...
# Generating embeddings for 14 texts in 1 batches...
# Node ID =  1214
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 12 texts in 1 batches...
# Generating embeddings for 6 texts in 1 batches...
# Generating embeddings for 2 texts in 1 batches...
# Node ID =  1215
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 28 texts in 1 batches...
# Node ID =  1216
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 15 texts in 1 batches...
# Node ID =  1217
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 69 texts in 3 batches...
# Node ID =  1218
# Process node content ........
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 1 texts in 1 batches...
# Generating embeddings for 3 texts in 1 batches...
# Generating embeddings for 13 texts in 1 batches...
# Generating embeddings for 22 texts in 1 batches...

# %%
# Save fully processed content tree
with open('genchem_with_embedding.pkl','wb') as f:
    pickle.dump(tree, f)

# %%
with open('genchem_with_embedding.pkl', 'rb') as f:
    tree = pickle.load(f)
nodes = tree.tree_node_iterator()

for node in nodes[28:30]:
    print(node.header)
    print(node.summary)
    print(node.content_text)
    print(node.questions)
# Out:
# The Domains of Chemistry
# Chemists study matter and energy in macroscopic, microscopic, and symbolic domains, using observations, imagination, and specialized language to describe and interpret chemical behavior.
# Chemists study and describe the behavior of matter and energy in three different domains: macroscopic, microscopic, and symbolic. These domains provide different ways of considering and describing chemical behavior.
#
# Macro is a Greek word that means "large." The macroscopic domain is familiar to us: It is the realm of everyday things that are large enough to be sensed directly by human sight or touch. In daily life, this includes the food you eat and the breeze you feel on your face. The macroscopic domain includes everyday and laboratory chemistry, where we observe and measure physical and chemical properties such as density, solubility, and flammability.
#
# Micro comes from Greek and means "small." The microscopic domain of chemistry is often visited in the imagination. Some aspects of the microscopic domain are visible through standard optical microscopes, for example, many biological cells. More sophisticated instruments are capable of imaging even smaller entities such as molecules and atoms (see Figure $1.5(\mathbf{b})$ ).
#
# However, most of the subjects in the microscopic domain of chemistry are too small to be seen even with the most advanced microscopes and may only be pictured in the mind. Other components of the microscopic domain include ions and electrons, protons and neutrons, and chemical bonds, each of which is far too small to see.
#
# The symbolic domain contains the specialized language used to represent components of the macroscopic and microscopic domains. Chemical symbols (such as those used in the periodic table), chemical formulas, and chemical equations are part of the symbolic domain, as are graphs, drawings, and calculations. These symbols play an important role in chemistry because they help interpret the behavior of the macroscopic domain in terms of the components of the microscopic domain. One of the challenges for students learning chemistry is recognizing that the same symbols can represent different things in the macroscopic and microscopic domains, and one of the features that makes chemistry fascinating is the use of a domain that must be imagined to explain behavior in a domain that can be observed.
#
# A helpful way to understand the three domains is via the essential and ubiquitous substance of water. That water is a liquid at moderate temperatures, will freeze to form a solid at lower temperatures, and boil to form a gas at higher temperatures (Figure 1.5) are macroscopic observations. But some properties of water fall into the microscopic domain-what cannot be observed with the naked eye. The description of water as comprising two hydrogen atoms and one oxygen atom, and the explanation of freezing and boiling in terms of attractions between these molecules, is within the microscopic arena. The formula $\mathrm{H}_{2} \mathrm{O}$, which can describe water at either the macroscopic or microscopic levels, is an example of the symbolic domain. The abbreviations $(g)$ for gas, $(s)$ for solid, and $(l)$ for liquid are also symbolic.
# ![Image](Chapter_1_images/img-4.jpeg)
#
# Figure 1.5 (a) Moisture in the air, icebergs, and the ocean represent water in the macroscopic domain. (b) At the molecular level (microscopic domain), gas molecules are far apart and disorganized, solid water molecules are close together and organized, and liquid molecules are close together and disorganized. (c) The formula $\mathrm{H}_{2} \mathrm{O}$ symbolizes water, and $(g),(s)$, and $(l)$ symbolize its phases. Note that clouds actually comprise either very small liquid water droplets or solid water crystals; gaseous water in our atmosphere is not visible to the naked eye, although it may be sensed as humidity. (credit a: modification of work by "Gorkaazk"/Wikimedia Commons)
# ['What are the three domains in which chemists study matter and energy?', 'How does the macroscopic domain relate to everyday objects and phenomena?', 'What is the significance of the microscopic domain in chemistry?', 'How do chemists use the symbolic domain to represent chemical phenomena?', 'What are some examples of macroscopic observations in chemistry?', 'How is water described in the microscopic domain?', 'What is the chemical formula for water and what does it represent?', 'How do phase symbols like \\( (g) \\), \\( (s) \\), and \\( (l) \\) relate to the symbolic domain?', 'What role does imagination play in understanding the microscopic domain?', 'How do the macroscopic, microscopic, and symbolic domains interconnect in chemistry?', 'What challenges do students face when learning about the different domains in chemistry?', 'How do macroscopic properties of water relate to its microscopic structure?', 'What does the symbolic formula \\( \\text{H}_2\\text{O} \\) illustrate about water?', 'Why is the symbolic domain important for interpreting macroscopic observations?', 'What are some entities included in the microscopic domain?', 'How do chemists describe the behavior of gas, solid, and liquid water molecules?', 'What is the importance of recognizing that symbols can represent different things in different domains?', 'How does Figure 1.5 illustrate the differences and connections between the macroscopic, microscopic, and symbolic domains?']
# Chapter 1 1.2 Phases and Classification of Matter
# Matter exists in solid, liquid, gas, and plasma states. Mass measures matter, while weight is gravity's force on it. Matter conservation states total matter remains constant during changes.
# By the end of this section, you will be able to:
#
# - Describe the basic properties of each physical state of matter: solid, liquid, and gas
# - Distinguish between mass and weight
# - Apply the law of conservation of matter
# - Classify matter as an element, compound, homogeneous mixture, or heterogeneous mixture with regard to its physical state and composition
# - Define and give examples of atoms and molecules
#
# Matter is defined as anything that occupies space and has mass, and it is all around us. Solids and liquids are more obviously matter: We can see that they take up space, and their weight tells us that they have mass. Gases are also
#
# matter; if gases did not take up space, a balloon would not inflate (increase its volume) when filled with gas.
# Solids, liquids, and gases are the three states of matter commonly found on earth (Figure 1.6). A solid is rigid and possesses a definite shape. A liquid flows and takes the shape of its container, except that it forms a flat or slightly curved upper surface when acted upon by gravity. (In zero gravity, liquids assume a spherical shape.) Both liquid and solid samples have volumes that are very nearly independent of pressure. A gas takes both the shape and volume of its container.
# ![Image](Chapter_1_images/img-5.jpeg)
#
# Figure 1.6 The three most common states or phases of matter are solid, liquid, and gas.
#
# A fourth state of matter, plasma, occurs naturally in the interiors of stars. A plasma is a gaseous state of matter that contains appreciable numbers of electrically charged particles (Figure 1.7). The presence of these charged particles imparts unique properties to plasmas that justify their classification as a state of matter distinct from gases. In addition to stars, plasmas are found in some other high-temperature environments (both natural and man-made), such as lightning strikes, certain television screens, and specialized analytical instruments used to detect trace amounts of metals.
#
# ![Image](Chapter_1_images/img-6.jpeg)
#
# Figure 1.7 A plasma torch can be used to cut metal. (credit: "Hypertherm"/Wikimedia Commons)
#
# **Link to Learning**
#
# In a tiny cell in a plasma television, the plasma emits ultraviolet light, which in turn causes the display at that location to appear a specific color. The composite of these tiny dots of color makes up the image that you see. Watch this video (http://openstaxcollege.org/1/16plasma) to learn more about plasma and the places you encounter it.
#
# Some samples of matter appear to have properties of solids, liquids, and/or gases at the same time. This can occur when the sample is composed of many small pieces. For example, we can pour sand as if it were a liquid because it is composed of many small grains of solid sand. Matter can also have properties of more than one state when it is a mixture, such as with clouds. Clouds appear to behave somewhat like gases, but they are actually mixtures of air (gas) and tiny particles of water (liquid or solid).
#
# The mass of an object is a measure of the amount of matter in it. One way to measure an object's mass is to measure the force it takes to accelerate the object. It takes much more force to accelerate a car than a bicycle because the car has much more mass. A more common way to determine the mass of an object is to use a balance to compare its mass with a standard mass.
#
# Although weight is related to mass, it is not the same thing. Weight refers to the force that gravity exerts on an object. This force is directly proportional to the mass of the object. The weight of an object changes as the force of gravity changes, but its mass does not. An astronaut's mass does not change just because she goes to the moon. But her weight on the moon is only one-sixth her earth-bound weight because the moon's gravity is only one-sixth that of the earth's. She may feel "weightless" during her trip when she experiences negligible external forces (gravitational or any other), although she is, of course, never "massless."
#
# The law of conservation of matter summarizes many scientific observations about matter: It states that there is no detectable change in the total quantity of matter present when matter converts from one type to another (a chemical change) or changes among solid, liquid, or gaseous states (a physical change). Brewing beer and the operation of batteries provide examples of the conservation of matter (Figure 1.8). During the brewing of beer, the ingredients (water, yeast, grains, malt, hops, and sugar) are converted into beer (water, alcohol, carbonation, and flavoring substances) with no actual loss of substance. This is most clearly seen during the bottling process, when glucose turns into ethanol and carbon dioxide, and the total mass of the substances does not change. This can also be seen in a
#
# lead-acid car battery: The original substances (lead, lead oxide, and sulfuric acid), which are capable of producing electricity, are changed into other substances (lead sulfate and water) that do not produce electricity, with no change in the actual amount of matter.
# ![Image](Chapter_1_images/img-7.jpeg)
#
# Figure 1.8 (a) The mass of beer precursor materials is the same as the mass of beer produced: Sugar has become alcohol and carbon dioxide. (b) The mass of the lead, lead oxide, and sulfuric acid consumed by the production of electricity is exactly equal to the mass of lead sulfate and water that is formed.
#
# Although this conservation law holds true for all conversions of matter, convincing examples are few and far between because, outside of the controlled conditions in a laboratory, we seldom collect all of the material that is produced during a particular conversion. For example, when you eat, digest, and assimilate food, all of the matter in the original food is preserved. But because some of the matter is incorporated into your body, and much is excreted as various types of waste, it is challenging to verify by measurement.
# ['What are the four states of matter?', 'How does a solid differ from a liquid in terms of shape and volume?', 'What is the defining characteristic of a gas in relation to its container?', 'What unique property does plasma have compared to other states of matter?', 'How is mass different from weight?', 'Why does an astronaut weigh less on the moon than on Earth?', 'What does the law of conservation of matter state?', 'Can you give an example of the law of conservation of matter in a chemical change?', 'What is an element in terms of matter classification?', 'How is a compound different from an element?', 'What distinguishes a homogeneous mixture from a heterogeneous mixture?', 'What is an atom?', 'How is a molecule formed?', 'Why are gases considered matter?', 'What happens to the shape of a liquid in zero gravity?', 'What is the role of electrically charged particles in plasma?', 'How does plasma in a television screen produce color?', 'Why can sand behave like a liquid?', 'What are clouds composed of in terms of states of matter?', 'How does the mass of an object affect the force needed to accelerate it?', 'Why does weight change with gravitational force but mass does not?', 'What happens to the total mass of substances during the brewing of beer?', 'How does a lead-acid battery demonstrate the conservation of matter?', 'What is a practical example of plasma found in nature?', 'What is the relationship between mass and the force of gravity?', 'How does the conservation of matter apply to digestion?', 'What is the significance of a balance in measuring mass?', 'Why might it be difficult to verify the conservation of matter outside a laboratory?', 'What happens to the volume of a gas when it is placed in a container?', 'What is the significance of the law of conservation of matter in scientific observations?']
